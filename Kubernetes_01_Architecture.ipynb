# %% [markdown]
# *Kubernetes* popularly known as (K8s) is a system for automating deployment, scaling, and managing containerized applications.
#
# - Kubernetes, also known as K8s, i18n >> internalatization, l10n >> localization
# - originally developed by google , but now its open source system
# - currently maintained by CNCF >> Cloud Native Compute Foundation

# %% [markdown]
# ### Kubernetes Architecture High level overview

# %% [markdown]
# ![Division%20of%20kubernets.png](attachment:Division%20of%20kubernets.png)

# %% [markdown]
# ### Kubernetes detailed architecture

# %% [markdown]
# ![kubernetes.png](attachment:kubernetes.png)

# %% [markdown]
# ## Worker Nodes:
#
# 1. Containers:
#
#     In general, a container is an isolated “micro-application” with all the necessary software packages and libraries.
#
# 2. Pods:
# - Pods group together two or more containers and are a key part of the K8s architecture.
# - If a pod fails, K8s can automatically replace it, add more CPU and memory, and even replicate it to scale out. Pods are assigned IP addresses.
# - A “controller” manages a group of pods, which together form a scalable “workload.”
# - The pods are connected via “services,” which represent the entirety of the workload.
# - In spite of scaling or destruction of some pods, a service balances web traffic across the pods. It’s also important to note that storage volumes are attached to pods and are exposed to containers within those pods.
#
# 3. Node:
# - A pod can be scheduled on a node with the help of a physical or virtual server.
# - A container runtime, a kubelet pod, and a Kube-proxy pod are all installed on every node (more on those three items to come).
# - Manually and automatically scaling node groups (also called autoscaling groups or node pool groups) is possible.
#
# 4. Container Runtime:
# - The container runtime is the software that allows containers to run. Containers, Docker, and CRI-O are popular container runtime examples.
#
# 5. Kubelet:
# - A kubelet runs on each node and sends information to Kubernetes master about the state and health of containers.
#
# 6. Kube-proxy:
# - The Kube-proxy component is installed on each node and is responsible for maintaining network services on worker nodes. - - It is also in charge of maintaining network rules, allowing network communication between services and pods, and routing network traffic.
#
# 7. Volumes:
# - K8s storage volumes allow long-term data storage that is accessible throughout the pod’s lifespan.
# - A pod’s containers can share a storage volume. A node can also access a storage volume directly.
#
# 8. Services:
# - A Kubernetes service is a collection of pods that cooperate. An example of a K8s service is shown below.
#
#
# ## Controller plane:
#
#
# #### Controller Plane:
# - A cluster’s main controlling unit is the Kubernetes master.
# - It manages the entire K8s cluster, including workloads, and serves as the cluster’s communication interface.
# - The Kubernetes controller plane is made up of several parts. These components enable Kubernetes to run highly available applications.
# - The following are the primary components of the Kubernetes control plane : API server, Scheduler. Controller Manager, etcd.
#
# 1. API Server:
# - JSON data is sent over HTTP.
# - It serves as Kubernetes’s internal and external interface.
# - It processes requests, validates them, and instructs the appropriate service or controller to update the state object in etcd, as well as allowing users to configure workloads across the cluster.
#
# 2. Scheduler:
# - evaluates nodes to determine where an unscheduled pod should be placed based on CPU and Memory requests, policies, label affinities, and workload data locality
#
# 3. Etcd:
# - etcd stores the cluster’s overall configuration data (i.e., the state and details of a pod), thereby representing the cluster’s state in Kubernetes master nodes.
# - The API Server monitors the cluster and makes changes to the cluster to match the desired state set using etcd data.
#
# 4. Controller:
# - A controller is a control loop that compares the desired and actual states of the K8s cluster and connects with the API server to create, update, and delete the resources it manages.
# - The label selectors in the controller determine the set of pods that the controller may control.
# - Replication Controller (scales pods),
# - DeamonSet Controller (ensures each node gets one copy of a designated pod),
# - Job Controller (runs software at a specific time)
# - Cronjob Controller (schedules jobs that run periodically)
# - StatefulSet Controller (controls stateful applications)
# - Deployment Controller (controls stateless applications).
#
#     are all examples of K8s controllers

# %% [markdown]
# ## Why Kubernetes?
#
# - app complexity - deployment trade off >> s/w engg

# %% [markdown]
# ## Advantages

# %% [markdown]
# - highly scalable and highly available. It provide the feature self- healing, automatic rollback , scaling
# - it will make it easy scale and down as when needed
# - it's portable, it will deploy on any infra.
# - It runs on-premises,, public cloud, hybrid
# - its open source, uniform way to package, deploy and manage application

# %% [markdown]
# ## Disadvantages

# %% [markdown]
# 1. Complexity
#     - setup is complex
#     - it required highly skilled personal to setup, manage and maintain.
#     - to setup in production env required high level of expertise.
#
# 2. Cost
#     - it require certain level of resources [HW, persons]

# %% [markdown]
# ## Which Companies uses Kubernetes

# %% [markdown]
# Small Company - Not Requires [Cost and Resources]
#
#
# Mid Scale Company - Ther will used managed service by the cloud provider
#                                 1. AWS EKS
#                                 2. Google GKE
#                                 3. Azure AKS
#
#
# Large Scale - On-premise.
